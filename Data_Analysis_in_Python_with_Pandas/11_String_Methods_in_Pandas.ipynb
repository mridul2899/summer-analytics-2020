# %% [markdown]
# This tutorial has been taken from **[Data School](https://www.youtube.com/channel/UCnVzApLJE2ljPZSeQylSEyg)**.<br>
# The link for the tutorial video can be found [here](https://youtu.be/bofaC0IckHo).

# %%
import pandas as pd

# %%
'hello'.upper() # a string method
# Out:
# 'HELLO'

# %%
orders = pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.item_name.str.upper() # we need to use str
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %%
orders[orders.item_name.str.contains('Chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %% [markdown]
# Find more methods in String Handling in Pandas API Reference.

# %%
# multiple string methods together
# like the below line of code removes square brackets
orders.choice_description.str.replace('[', '').str.replace(']', '')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object

# %%
# same thing using regular expressions
orders.choice_description.str.replace('[\[\]]', '')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object
